# %%
# PASSO 1: Instalar versões específicas compatíveis (execute esta célula)
#!pip install --user --force-reinstall numpy==1.21.1
#!pip install --user --force-reinstall pandas==1.5.3
#!pip install --user --force-reinstall matplotlib==3.7.3
#!pip install --user --force-reinstall seaborn==0.11.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Carrega os dados
train = pd.read_csv("/workspaces/titanic-ml-project/data/train.csv")

# Análise de sobrevivência por diferentes características
print("📊 Análise de sobrevivência por características...")

plt.figure(figsize=(15, 10))

# Sobrevivência por sexo
plt.subplot(2, 3, 1)
sns.countplot(data=train, x='Sex', hue='Survived')
plt.title('Sobrevivência por Sexo')

# Sobrevivência por classe
plt.subplot(2, 3, 2)
sns.countplot(data=train, x='Pclass', hue='Survived')
plt.title('Sobrevivência por Classe')

# Sobrevivência por porto de embarque
plt.subplot(2, 3, 3)
sns.countplot(data=train, x='Embarked', hue='Survived')
plt.title('Sobrevivência por Porto de Embarque')

# Idade vs Sobrevivência
plt.subplot(2, 3, 4)
sns.boxplot(data=train, x='Survived', y='Age')
plt.title('Idade vs Sobrevivência')

# Tarifa vs Sobrevivência
plt.subplot(2, 3, 5)
sns.boxplot(data=train, x='Survived', y='Fare')
plt.title('Tarifa vs Sobrevivência')

# Irmãos/Cônjuges vs Sobrevivência
plt.subplot(2, 3, 6)
sns.countplot(data=train, x='SibSp', hue='Survived')
plt.title('Irmãos/Cônjuges vs Sobrevivência')

plt.tight_layout()
plt.show()

print("✅ Análise completa realizada com sucesso!")
# Out:
# 📊 Análise de sobrevivência por características...
# ✅ Análise completa realizada com sucesso!

# %%
#!pip show pandas
# !pip install --upgrade seaborn
# !pip install --upgrade seaborn
# !pip install --upgrade pandas
